# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/rayquaza/Desktop/mlops/pandas/winemag-data-130k-v2.csv',index_col=0)
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
df.price.dtype
# Out:
# dtype('float64')

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df.description[pd.isnull(df.country)]
# Out:
# 913       Amber in color, this wine has aromas of peach ...
# 3131      Soft, fruity and juicy, this is a pleasant, si...
# 4243      Violet-red in color, this semisweet wine has a...
# 9509      This mouthwatering blend starts with a nose of...
# 9750      This orange-style wine has a cloudy yellow-gol...
#                                 ...
# 124176    This Swiss red blend is composed of four varie...
# 129407    Dry spicy aromas of dusty plum and tomato add ...
# 129408    El Capricho is one of Uruguay's more consisten...
# 129590    A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900    This wine offers a delightful bouquet of black...
# Name: description, Length: 63, dtype: object

# %%
df.iloc[913]
# Out:
# country                                                                NaN
# description              Amber in color, this wine has aromas of peach ...
# designation                                                 Asureti Valley
# points                                                                  87
# price                                                                 30.0
# province                                                               NaN
# region_1                                                               NaN
# region_2                                                               NaN
# taster_name                                                  Mike DeSimone
# taster_twitter_handle                                       @worldwineguys
# title                       Gotsa Family Wines 2014 Asureti Valley Chinuri
# variety                                                            Chinuri
# ...

# %%
df.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
df[pd.isnull(df.region_1)]
# Out:
#             country                                        description  \
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 15          Germany  Zesty orange peels and apple notes abound in t...
# 36            Chile  White flower, lychee and apple aromas carry th...
# 44            Chile  A berry aroma comes with cola and herb notes. ...
# ...             ...                                                ...
# 129956  New Zealand  The blend is 44% Merlot, 33% Cabernet Sauvigno...
# 129958  New Zealand  This blend of Cabernet Sauvignon-Merlot and Ca...
# 129960     Portugal  Fresh and fruity, this is full of red cherry f...
# 129963       Israel  A bouquet of black cherry, tart cranberry and ...
# 129966      Germany  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                               designation  points  price  \
# ...

# %%
df.region_1.fillna("lol")
# Out:
# 0                        Etna
# 1                         lol
# 2           Willamette Valley
# 3         Lake Michigan Shore
# 4           Willamette Valley
#                  ...
# 129966                    lol
# 129967                 Oregon
# 129968                 Alsace
# 129969                 Alsace
# 129970                 Alsace
# Name: region_1, Length: 129971, dtype: object

# %%
df.taster_name.replace('Roger Voss','Joy Palit')
# Out:
# 0              Kerin O’Keefe
# 1                  Joy Palit
# 2               Paul Gregutt
# 3         Alexander Peartree
# 4               Paul Gregutt
#                  ...
# 129966    Anna Lee C. Iijima
# 129967          Paul Gregutt
# 129968             Joy Palit
# 129969             Joy Palit
# 129970             Joy Palit
# Name: taster_name, Length: 129971, dtype: object

# %%
df.price.astype('str')
# Out:
# 0          nan
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: object

# %%
x=df.region_1.fillna('Unknown')
df.region_1.fillna('Unkown').value_counts().sort_values(ascending=False)
# Out:
# region_1
# Unkown                  21247
# Napa Valley              4480
# Columbia Valley (WA)     4124
# Russian River Valley     3091
# California               2629
#                         ...
# Offida Rosso                1
# Corton Perrières            1
# Isle St. George             1
# Geelong                     1
# Paestum                     1
# Name: count, Length: 1230, dtype: int64
