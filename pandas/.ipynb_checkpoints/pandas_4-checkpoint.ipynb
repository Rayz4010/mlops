# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/rayquaza/Desktop/mlops/pandas/winemag-data-130k-v2.csv',index_col=0)
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
df.groupby('price').price.count()
# Out:
# price
# 4.0        11
# 5.0        46
# 6.0       120
# 7.0       433
# 8.0       892
#          ...
# 1900.0      1
# 2000.0      2
# 2013.0      1
# 2500.0      2
# 3300.0      1
# Name: price, Length: 390, dtype: int64

# %%
df.price.value_counts()
# Out:
# price
# 20.0     6940
# 15.0     6066
# 25.0     5805
# 30.0     4951
# 18.0     4883
#          ...
# 574.0       1
# 630.0       1
# 764.0       1
# 319.0       1
# 848.0       1
# Name: count, Length: 390, dtype: int64

# %%
df.groupby('price').points.min()
# Out:
# price
# 4.0       82
# 5.0       80
# 6.0       80
# 7.0       80
# 8.0       80
#           ..
# 1900.0    98
# 2000.0    96
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
df.groupby('country').apply(lambda x:x.price.iloc[0])
# Out:
# /var/folders/wd/28dthdw16pg5_wrd6f76dg4h0000gn/T/ipykernel_9761/1573588835.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('country').apply(lambda x:x.price.iloc[0])
# country
# Argentina                 30.0
# Armenia                   14.0
# Australia                 18.0
# Austria                   12.0
# Bosnia and Herzegovina    13.0
# Brazil                    36.0
# Bulgaria                   9.0
# Canada                    30.0
# Chile                     15.0
# China                     18.0
# Croatia                   20.0
# Cyprus                    17.0
# Czech Republic            25.0
# Egypt                      NaN
# England                   46.0
# ...

# %%
df.iloc[:5,1]
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# Name: description, dtype: object

# %%
df.groupby(['country','price']).apply(lambda x:x.loc[:,'winery'])
# Out:
# /var/folders/wd/28dthdw16pg5_wrd6f76dg4h0000gn/T/ipykernel_9761/2585232059.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby(['country','price']).apply(lambda x:x.loc[:,'winery'])
# country    price
# Argentina  4.0    29553          Broke Ass
#            5.0    23437           Terrenal
#                   112639           Zamarro
#                   125826     Toca Diamonte
#            6.0    2618         Funky Llama
#                                  ...
# Uruguay    60.0   71451     Familia Deicas
#                   72049     Familia Deicas
#            65.0   19512           Marichal
#            120.0  38811     Familia Deicas
#            130.0  93548     Familia Deicas
# ...

# %%
df.groupby(['country','price']).points.agg([len,min,max])
# Out:
# /var/folders/wd/28dthdw16pg5_wrd6f76dg4h0000gn/T/ipykernel_9761/525242591.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['country','price']).points.agg([len,min,max])
# /var/folders/wd/28dthdw16pg5_wrd6f76dg4h0000gn/T/ipykernel_9761/525242591.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(['country','price']).points.agg([len,min,max])
#                  len  min  max
# country   price
# Argentina 4.0      1   84   84
#           5.0      3   80   84
#           6.0     11   81   85
#           7.0     19   81   87
#           8.0     54   80   87
# ...              ...  ...  ...
# ...

# %%
x=df.groupby(['country','price']).description.agg([len])
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
x.index
# Out:
# MultiIndex([('Argentina',   4.0),
#             ('Argentina',   5.0),
#             ('Argentina',   6.0),
#             ('Argentina',   7.0),
#             ('Argentina',   8.0),
#             ('Argentina',   9.0),
#             ('Argentina',  10.0),
#             ('Argentina',  11.0),
#             ('Argentina',  12.0),
#             ('Argentina',  13.0),
#             ...
#             (  'Uruguay',  43.0),
#             (  'Uruguay',  44.0),
#             (  'Uruguay',  45.0),
#             (  'Uruguay',  46.0),
#             (  'Uruguay',  50.0),
#             (  'Uruguay',  52.0),
#             (  'Uruguay',  60.0),
#             (  'Uruguay',  65.0),
#             (  'Uruguay', 120.0),
#             (  'Uruguay', 130.0)],
#            names=['country', 'price'], length=2238)

# %%
x=x.reset_index()

# %%
 x.sort_values(by='len')
# Out:
#         country  price   len
# 0     Argentina    4.0     1
# 1018    Germany  144.0     1
# 1019    Germany  150.0     1
# 1020    Germany  154.0     1
# 1022    Germany  165.0     1
# ...         ...    ...   ...
# 2077         US   40.0  2157
# 2072         US   35.0  2240
# 2067         US   30.0  2613
# 2057         US   20.0  2736
# 2062         US   25.0  2860
#
# [2238 rows x 3 columns]

# %%
df.price.sort_values(ascending=False)
# Out:
# 80290     3300.0
# 15840     2500.0
# 98380     2500.0
# 120391    2013.0
# 113564    2000.0
#            ...
# 129844       NaN
# 129860       NaN
# 129863       NaN
# 129893       NaN
# 129964       NaN
# Name: price, Length: 129971, dtype: float64

# %%
x.sort_index(ascending=False)
# Out:
#         country  price  len
# 2237    Uruguay  130.0    1
# 2236    Uruguay  120.0    1
# 2235    Uruguay   65.0    1
# 2234    Uruguay   60.0    3
# 2233    Uruguay   52.0    1
# ...         ...    ...  ...
# 4     Argentina    8.0   54
# 3     Argentina    7.0   19
# 2     Argentina    6.0   11
# 1     Argentina    5.0    3
# 0     Argentina    4.0    1
#
# [2238 rows x 3 columns]

# %%
g=df.groupby(['country','price'])

# %%
df.sort_values(by=['country','price'],ascending=False)
# Out:
#        country                                        description  \
# 93548  Uruguay  Dense, cedary, rubbery aromas of blackberry an...
# 38811  Uruguay  Ignore the crazy price on this aged Tannat and...
# 19512  Uruguay  A lot has been thrown at this Tannat, and thus...
# 15750  Uruguay  A rich, heady bouquet offers aromas of blackbe...
# 71451  Uruguay  Rusty in color, this maturing Tannat-led blend...
# ...        ...                                                ...
# 44851      NaN  This wine has aromas of honeysuckle and lemon ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 11348      NaN  Light and fruity, this is a wine that has some...
# 16749      NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 57612      NaN  Winemaker: Gordon Newton Johnson. This is such...
#
#                                    designation  points  price    province  \
# 93548                           Massimo Deicas      90  130.0     Juanico
# ...

# %%
df.iloc[:,[0,4]]
# Out:
#        country  price
# 93548  Uruguay  130.0
# 38811  Uruguay  120.0
# 19512  Uruguay   65.0
# 15750  Uruguay   60.0
# 71451  Uruguay   60.0
# ...        ...    ...
# 44851      NaN    6.0
# 3131       NaN    NaN
# 11348      NaN    NaN
# 16749      NaN    NaN
# 57612      NaN    NaN
#
# [129971 rows x 2 columns]
