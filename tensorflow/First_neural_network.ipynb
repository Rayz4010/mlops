# %% [markdown]
# # **My first Neural Network with tensorflow**

# %% [markdown]
# ## **Data Importing**

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/rayquaza/Documents/desk/mlops/tensorflow/databases/Churn.csv')
df.head()
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %% [markdown]
# ### **Data splitting**

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x=pd.get_dummies(df.drop(['Churn','Customer ID'],axis=1))
y=df['Churn'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=100)

# %%
x_train
# Out:
#       Senior Citizen  tenure  Monthly Charges  Gender_Female  Gender_Male  \
# 4927               0      62            60.15          False         True
# 390                0       1            44.00          False         True
# 1007               0      18            90.10           True        False
# 6390               0      58            19.55           True        False
# 2939               0      53            97.75          False         True
# ...              ...     ...              ...            ...          ...
# 79                 1      30            74.75          False         True
# 3927               0      11            34.70          False         True
# 5955               0      20            55.00          False         True
# 6936               0      65           110.80           True        False
# 5640               0       6            20.65          False         True
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %%
x_test
# Out:
#       Senior Citizen  tenure  Monthly Charges  Gender_Female  Gender_Male  \
# 4881               0      50            20.55          False         True
# 1541               0      63            80.30          False         True
# 1289               0      64            19.55          False         True
# 6937               0       5            80.15          False         True
# 4874               0       7            19.30           True        False
# ...              ...     ...              ...            ...          ...
# 4219               0       7            25.05          False         True
# 3989               0      51            81.15          False         True
# 6669               0      38           103.65           True        False
# 2101               0      69            99.50          False         True
# 6078               0      62           113.95           True        False
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %% [markdown]
# ## **Import dependencies**

# %%
# !pip install tensorflow==2.18.1
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().system('pip install tensorflow==2.18.1')
# ----> 2 from tensorflow.keras.models import Sequential, load_model
#       3 from tensorflow.keras.layers import Dense
#       4 from sklearn.metrics import accuracy_score
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## **Build and complie model**

# %% [markdown]
# ## **Fit predict and evaluate**

# %% [markdown]
# ## **saving and reloading**
