# %% [markdown]
# # Google Gemini

# %%
# !pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 42.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.7.0 which is incompatible.
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI as cg

# %%
api_key='AIzao'

# %%
model='gemini-1.5-flash'
llm=cg(model=model,google_api_key=api_key)

# %%
prompt='what is a waifu?'
response=llm.invoke(prompt)

print(response)
# Out:
# content='In anime and manga fandom, a "waifu" is a fictional female character that a fan has a strong romantic or affectionate attachment to.  It\'s essentially a term for a favorite female character who is idealized and often considered a romantic partner, though the relationship is entirely one-sided and exists only in the fan\'s imagination.  The term is often used playfully or ironically, but can also indicate a genuine and strong emotional connection to the character.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []} id='run--d2c62904-88c0-4950-8c60-e3742b9909d3-0' usage_metadata={'input_tokens': 5, 'output_tokens': 93, 'total_tokens': 98, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# # Open Ai

# %%
# !pip install langchain_openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.0 MB/s eta 0:00:00
# ...
