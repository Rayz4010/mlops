# %% [markdown]
# # **Machine Learning**
# <br>
#
# Types of ML<br>
#
# -->**Supervised Learning** <br>
# -->**Unsupervised Learning** <br>
# -->**Reinforcement** <br>
#
#
#
#
# <br><br><br>
# if data is continuous it's regression

# %% [markdown]
# ## **ML pipeline**
#
# **__Data_Pre-processing(if required)__**
# -->**Step 1: Import packages** <br>
# -->**Step 2: Load the dataset**<br>
# -->**Step 3: Check statistics of Datasets**<br>
# -->**Step 4: Split data into x axis and y axis**<br>
# -->**Steo 5: Split the dataset into training and testing**<br>
# -->**Step 6: Call and train the model**<br>
# -->**Step 7:Make prediction**<br>
# -->**Step 8:Model Evaluatuion**<br>
# -->**Step 9:create and end to end application**<br>
# -->**Step 10: Deploying**<br>

# %% [markdown]
# # **Home Price Prediction Model Linear Regression**

# %% [markdown]
# **y=mx+c**

# %% [markdown]
# ## **Data pipeline**

# %% [markdown]
# ### **Load the dataset**

# %%
import pandas as pd
from pandas import read_csv as rc

# %%
df=rc('/Users/rayquaza/Desktop/mlops/workshop/ICE-Workshop/datasets/linear regression/homeprices_singlevariable_linear_regression.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# ### **Split the dataset into x and y**

# %%
x=df[['area']]
y=df['price']

x,y
# Out:
# (   area
#  0  2600
#  1  3000
#  2  3200
#  3  3600
#  4  4000,
#  0    550000
#  1    565000
#  2    610000
#  3    680000
#  4    725000
#  Name: price, dtype: int64)

# %% [markdown]
# ### **Data Statistics**

# %%
df.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
df.describe()
# Out:
#               area          price
# count     5.000000       5.000000
# mean   3280.000000  626000.000000
# std     540.370243   74949.983322
# min    2600.000000  550000.000000
# 25%    3000.000000  565000.000000
# 50%    3200.000000  610000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %% [markdown]
# ### **Split the dataset in traing and testing**

# %% [markdown]
# because the data set is small so skip

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=90)

# %%
x_train
# Out:
#    area
# 4  4000
# 2  3200
# 1  3000
# 3  3600

# %%
x_test
# Out:
#    area
# 0  2600

# %% [markdown]
# ### **Call And train the model**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Make Predictions**

# %%
pred=lr.predict([[1500]])
# Out:
# /opt/anaconda3/envs/tf2.18/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pred
# Out:
# array([384297.94520548])

# %% [markdown]
# #### **Checking**

# %%
lr.coef_
# Out:
# array([135.78767123])

# %%
lr.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*1500+180616.43835616432
# Out:
# 384297.94520116434

# %% [markdown]
# ### **Model Evaluation**

# %%
from sklearn.metrics import r2_score as r2
